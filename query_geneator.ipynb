# %%
import pandas as pd
df=pd.read_csv("iecities.csv")

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
def make_query(row):
    print("insert into ireland_cities (city,lat, long, country, iso2, admin_name, capital, population) values (\'%s\', %f, %f, \'%s\',  \'%s\',  \'%s\',\'%s\', %d);" %(row[0],row[1], row[2], row[3], row[4], row[5], row[6], row[7]))
t=df.apply(make_query, axis=1)
# Out:
# insert into ireland_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Dublin', 53.349700, -6.260300, 'Ireland',  'IE',  'Dublin','primary', 1173179);
# insert into ireland_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Cork', 51.900000, -8.473100, 'Ireland',  'IE',  'Cork','admin', 208669);
# insert into ireland_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Galway', 53.272900, -9.041800, 'Ireland',  'IE',  'Galway','admin', 79504);
# insert into ireland_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Limerick', 52.665300, -8.623800, 'Ireland',  'IE',  'Limerick','admin', 58319);
# insert into ireland_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Waterford', 52.258300, -7.119000, 'Ireland',  'IE',  'Waterford','admin', 48369);
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
northern_ir=("Antrim and Newtownabbey", "Ards and North Down", "Armagh, Banbridge and Craigavon","Belfast", "Causeway Coast and Glens", "Derry and Strabane","Fermanagh and Omagh", "Lisburn and Castlereagh",
"Mid and East Antrim",	
"Mid Ulster",
"Newry, Mourne and Down")

df=pd.read_csv("gb.csv")
def make_query(row):
    if row[5] in northern_ir:
        print("insert into ireland_cities (city,lat, long, country, iso2, admin_name, capital, population) values (\'%s\', %f, %f, \'%s\',  \'%s\',  \'%s\',\'%s\', %d);" %(row[0],row[1], row[2], row[3], row[4], row[5], row[6], row[7]))
    else:
        print("insert into gb_cities (city,lat, long, country, iso2, admin_name, capital, population) values (\'%s\', %f, %f, \'%s\',  \'%s\',  \'%s\',\'%s\', %f);" %(row[0],row[1], row[2], row[3], row[4], row[5], row[6], row[7]))
t=df.apply(make_query, axis=1)
# Out:
# insert into gb_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('London', 51.507200, -0.127500, 'United Kingdom',  'GB',  'London, City of','primary', 10979000.000000);
# insert into gb_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Birmingham', 52.480000, -1.902500, 'United Kingdom',  'GB',  'Birmingham','nan', 2897303.000000);
# insert into gb_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Manchester', 53.479400, -2.245300, 'United Kingdom',  'GB',  'Manchester','nan', 2705000.000000);
# insert into gb_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Leeds', 53.799700, -1.549200, 'United Kingdom',  'GB',  'Leeds','nan', 1901934.000000);
# insert into gb_cities (city,lat, long, country, iso2, admin_name, capital, population) values ('Newcastle', 55.007700, -1.657800, 'United Kingdom',  'GB',  'Newcastle upon Tyne','nan', 1650000.000000);
# ...
